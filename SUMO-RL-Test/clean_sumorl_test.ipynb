# %% [markdown]
# ## Intialize

# %% [markdown]
# ### Mount

# %%
from google.colab import drive
import os

if not os.path.exists("/content/drive"):
    print("Drive not mounted. Mounting now...")
    drive.mount('/content/drive')
else:
    print("Drive already mounted")
# Out:
# Drive already mounted

# %% [markdown]
# ### Packages

# %%
import subprocess

try:
    subprocess.run(["sumo", "--version"], check=True, stdout=subprocess.PIPE)
    print("Packages are installed")
except FileNotFoundError:
    # !sudo add-apt-repository -y ppa:sumo/stable
    # !sudo apt-get update
    # !sudo apt-get install -y sumo sumo-tools sumo-doc
    # !source ~/.bashrc
    # !sumo --version
# Out:
# Packages are installed

# %%
# !pip install traci
# !pip install sumo-rl
# !pip install stable_baselines3
# !pip install colorama
# !pip install optuna

# %%
import os

os.environ['SUMO_HOME'] = '/usr/share/sumo'

# %% [markdown]
# ## Files

# %% [markdown]
# ## Test

# %%
path_fold = "/content/drive/MyDrive/study/graduation_project/final/Code/project_files/TrafficManager/TrafficManager/" # data2_mosheerIsmail or data3_san_stefano

# %%
#!sumo -n "{path_net}" -r "{path_rou}" --no-step-log true

# %%
"/content/drive/"
# Out:
# '/content/drive/'

# %%
for i in range(100):
  # !python3 "{path_fold}SUMO-RL-Test/Main.py" -p "{path_fold}"  ##--optuna #--save-parameters
# Out:
# Streaming output truncated to the last 5000 lines.
# 16900.0 of 21600
# 16950.0 of 21600
# 17000.0 of 21600
# 17050.0 of 21600
# 17100.0 of 21600
# 17150.0 of 21600
# 17200.0 of 21600
# 17250.0 of 21600
# 17300.0 of 21600
# 17350.0 of 21600
# 17400.0 of 21600
# 17450.0 of 21600
# 17500.0 of 21600
# Step #17500.00 (1ms ~= 1000.00*RT, ~8000.00UPS,17550.0 of 21600
# 17600.0 of 21600
# 17650.0 of 21600
# 17700.0 of 21600
# 17750.0 of 21600
# 17800.0 of 21600
# 17850.0 of 21600
# 17900.0 of 21600
# 17950.0 of 21600
# 18000.0 of 21600
# 18050.0 of 21600
# 18100.0 of 21600
# 18150.0 of 21600
# 18200.0 of 21600
# 18250.0 of 21600
# 18300.0 of 21600
# 18350.0 of 21600
# 18400.0 of 21600
# 18450.0 of 21600
# 18500.0 of 21600
# 18550.0 of 21600
# 18600.0 of 21600
# Step #18600.00 (0ms ?*RT. ?UPS, TraCI: 13ms, vehicles TOT 446 ACT 12 B18650.0 of 21600
# 18700.0 of 21600
# 18750.0 of 21600
# 18800.0 of 21600
# 18850.0 of 21600
# 18900.0 of 21600
# 18950.0 of 21600
# 19000.0 of 21600
# ...

# %%
# !sumo -n "{path_fold}map.net.xml" -r "{path_fold}route.rou.xml" --tripinfo-output tripinfo.xml --statistic-output osm.statistics.xml
# Out:
# Error: File '/content/drive/MyDrive/study/graduation_project/final/Code/project_files/TrafficManager/TrafficManager/map.net.xml' is not accessible (No such file or directory).
# Quitting (on error).

# %%
get_sumo_statics()# normal
# Out:
# {'waiting_time': 1.46,
#  'speed': 9.34,
#  'waiting_vehicles': 516,
#  'time_loss': 6.36,
#  'depart_delay': 0.13}

# %%
get_sumo_statics() # crowd
# Out:
# {'waiting_time': 1.42,
#  'speed': 9.26,
#  'waiting_vehicles': 2014,
#  'time_loss': 6.89,
#  'depart_delay': 5.1}
